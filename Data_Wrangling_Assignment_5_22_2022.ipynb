# %% [markdown]
# <a href="https://colab.research.google.com/github/AmmAhhRin/Machine-Learning-/blob/main/Data_Wrangling_Assignment_5_22_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn    # machine learning
import numpy as np  # computation
import pandas as pd # data management

# %%
#1. Load Data
dataset = pd.read_csv("https://raw.githubusercontent.com/datasets/political_geography/main/data/uk_eng.csv")
dataset.head(10)
# Out:
#   administrative_area_level_1 administrative_area_level_2  \
# 0                     England                Bedfordshire
# 1                     England                Bedfordshire
# 2                     England                Bedfordshire
# 3                     England                Bedfordshire
# 4                     England                   Berkshire
# 5                     England                   Berkshire
# 6                     England                   Berkshire
# 7                     England                   Berkshire
# 8                     England                   Berkshire
# 9                     England                   Berkshire
#
#   administrative_area_level_3      tag                             features  \
# 0                     Bedford  borough                              Bedford
# 1        Central Bedfordshire  borough                 Central Bedfordshire
# 2                       Luton  borough                                Luton
# ...

# %%
#2. Know the dimensions
dataset.shape
# Out:
# (306, 7)

# %%
dataset.describe() #count, mean, std, min, max
# Out:
#        administrative_area_level_1 administrative_area_level_2  \
# count                          306                         306
# unique                           4                         115
# top                        England              Greater London
# freq                           240                          27
#
#        administrative_area_level_3      tag features  \
# count                          192      306       47
# unique                         191        4       47
# top                          Luton  borough  Bedford
# freq                             2      180        1
#
#                                                 url_shape  \
# count                                                 298
# unique                                                249
# top     https://geoportal1-ons.opendata.arcgis.com/dat...
# freq                                                   47
#
#                                 url
# count                           304
# ...

# %%
#3. Check the variables (numerical)
numVar = dataset.columns[dataset.dtypes != 'object']
dataset[numVar].head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#3. Check the variables (categorical)
catVar = dataset.columns[dataset.dtypes == 'object']
dataset[catVar].head(5)
# Out:
#   administrative_area_level_1 administrative_area_level_2  \
# 0                     England                Bedfordshire
# 1                     England                Bedfordshire
# 2                     England                Bedfordshire
# 3                     England                Bedfordshire
# 4                     England                   Berkshire
#
#   administrative_area_level_3      tag                             features  \
# 0                     Bedford  borough                              Bedford
# 1        Central Bedfordshire  borough                 Central Bedfordshire
# 2                       Luton  borough                                Luton
# 3                       Luton   county  Luton|Central Bedfordshire |Bedford
# 4            Bracknell Forest  borough                     Bracknell Forest
#
#                                            url_shape  \
# 0  https://geoportal1-ons.opendata.arcgis.com/dat...
# ...

# %%
#4. Missing values  #false=no missing, true=missing
dataset.isnull().head(5)
# Out:
#    administrative_area_level_1  administrative_area_level_2  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    administrative_area_level_3    tag  features  url_shape    url
# 0                        False  False     False      False  False
# 1                        False  False     False      False  False
# 2                        False  False     False      False  False
# 3                        False  False     False      False   True
# 4                        False  False     False      False  False

# %%
#5. How many percentage is missing?
dataset.isnull().sum()/len(dataset)
# Out:
# administrative_area_level_1    0.000000
# administrative_area_level_2    0.000000
# administrative_area_level_3    0.372549
# tag                            0.000000
# features                       0.846405
# url_shape                      0.026144
# url                            0.006536
# dtype: float64

# %%
#5. How many percentage of numerical variable is missing?
dataset[numVar].isnull().sum()/len(dataset)
# Out:
# Series([], dtype: float64)

# %%
#5. How many percentage of categorical variable is missing?
dataset[catVar].isnull().sum()/len(dataset)
# Out:
# administrative_area_level_1    0.000000
# administrative_area_level_2    0.000000
# administrative_area_level_3    0.372549
# tag                            0.000000
# features                       0.846405
# url_shape                      0.026144
# url                            0.006536
# dtype: float64

# %%
#6. Replace the missing value 
dataset.fillna("Fill missing value")
# Out:
#     administrative_area_level_1 administrative_area_level_2  \
# 0                       England                Bedfordshire
# 1                       England                Bedfordshire
# 2                       England                Bedfordshire
# 3                       England                Bedfordshire
# 4                       England                   Berkshire
# ..                          ...                         ...
# 301                       Wales           Rhondda Cynon Taf
# 302                       Wales                     Swansea
# 303                       Wales                     Torfaen
# 304                       Wales           Vale of Glamorgan
# 305                       Wales                     Wrexham
#
#     administrative_area_level_3      tag                             features  \
# 0                       Bedford  borough                              Bedford
# 1          Central Bedfordshire  borough                 Central Bedfordshire
# ...

# %%
#7 Replace value  
dataset['tag'].replace('borough', 'replacing values')
# Out:
# 0      replacing values
# 1      replacing values
# 2      replacing values
# 3                county
# 4      replacing values
#              ...
# 301              county
# 302                city
# 303    replacing values
# 304              county
# 305              county
# Name: tag, Length: 306, dtype: object

# %%
#8 Create the rows and add it with the orginal dataset #value of variables and instruct where the values should be stored
rowInsert = pd.Series(['Phnom Penh', 'Kampong Speu', 'Kampot', 'city', 'Unknown', 'https://drive.google.com/drive/my-drive', 'https://drive.google.com/drive/my-drive'] ,index = ['administrative_area_level_1','administrative_area_level_2','administrative_area_level_3', 'tag', 'features', 'url_shape', 'url'])
dataset.append(rowInsert, ignore_index=True)
# Out:
#     administrative_area_level_1 administrative_area_level_2  \
# 0                       England                Bedfordshire
# 1                       England                Bedfordshire
# 2                       England                Bedfordshire
# 3                       England                Bedfordshire
# 4                       England                   Berkshire
# ..                          ...                         ...
# 302                       Wales                     Swansea
# 303                       Wales                     Torfaen
# 304                       Wales           Vale of Glamorgan
# 305                       Wales                     Wrexham
# 306                  Phnom Penh                Kampong Speu
#
#     administrative_area_level_3      tag                             features  \
# 0                       Bedford  borough                              Bedford
# 1          Central Bedfordshire  borough                 Central Bedfordshire
# ...

# %%
#9 Choose the exact rows from the data set (call the rows)
#iloc: to call specific rows 
dataset.iloc[1:4]
# Out:
#   administrative_area_level_1 administrative_area_level_2  \
# 1                     England                Bedfordshire
# 2                     England                Bedfordshire
# 3                     England                Bedfordshire
#
#   administrative_area_level_3      tag                             features  \
# 1        Central Bedfordshire  borough                 Central Bedfordshire
# 2                       Luton  borough                                Luton
# 3                       Luton   county  Luton|Central Bedfordshire |Bedford
#
#                                            url_shape  \
# 1  https://geoportal1-ons.opendata.arcgis.com/dat...
# 2  https://geoportal1-ons.opendata.arcgis.com/dat...
# 3  https://geoportal1-ons.opendata.arcgis.com/dat...
#
#                                        url
# 1  https://www.centralbedfordshire.gov.uk/
# 2                  https://m.luton.gov.uk/
# 3                                      NaN

# %%
#9 Choose the exact rows from the data set 
#loc: to call based on specific values (only string)
dataset = dataset.set_index(dataset['tag']) 
dataset.loc['county'].head(5)
# Out:
#        administrative_area_level_1 administrative_area_level_2  \
# tag
# county                     England                Bedfordshire
# county                     England                   Berkshire
# county                     England             Buckinghamshire
# county                     England              Cambridgeshire
# county                     England                    Cheshire
#
#        administrative_area_level_3     tag  \
# tag
# county                       Luton  county
# county                         NaN  county
# county                         NaN  county
# county                         NaN  county
# county                         NaN  county
#
#                                                  features  \
# tag
# county                Luton|Central Bedfordshire |Bedford
# county  Bracknell Forest|Reading|Slough|West Berkshire...
# county                                    Buckinghamshire
# county                                                NaN
# ...

# %%
#10 rename the columns 
dataset.rename(columns={'tag':'tags'}).head(5)
# Out:
#         administrative_area_level_1 administrative_area_level_2  \
# tag
# borough                     England                Bedfordshire
# borough                     England                Bedfordshire
# borough                     England                Bedfordshire
# county                      England                Bedfordshire
# borough                     England                   Berkshire
#
#         administrative_area_level_3     tags  \
# tag
# borough                     Bedford  borough
# borough        Central Bedfordshire  borough
# borough                       Luton  borough
# county                        Luton   county
# borough            Bracknell Forest  borough
#
#                                     features  \
# tag
# borough                              Bedford
# borough                 Central Bedfordshire
# borough                                Luton
# county   Luton|Central Bedfordshire |Bedford
# borough                     Bracknell Forest
#
# ...

# %%
#11 delete columns
dataset.drop('administrative_area_level_1', axis=1).head(5)
# Out:
#         administrative_area_level_2 administrative_area_level_3      tag  \
# tag
# borough                Bedfordshire                     Bedford  borough
# borough                Bedfordshire        Central Bedfordshire  borough
# borough                Bedfordshire                       Luton  borough
# county                 Bedfordshire                       Luton   county
# borough                   Berkshire            Bracknell Forest  borough
#
#                                     features  \
# tag
# borough                              Bedford
# borough                 Central Bedfordshire
# borough                                Luton
# county   Luton|Central Bedfordshire |Bedford
# borough                     Bracknell Forest
#
#                                                  url_shape  \
# tag
# borough  https://geoportal1-ons.opendata.arcgis.com/dat...
# borough  https://geoportal1-ons.opendata.arcgis.com/dat...
# ...

# %%
#12 find unique value
dataset['features'].unique()
# Out:
# array(['Bedford', 'Central Bedfordshire', 'Luton',
#        'Luton|Central Bedfordshire |Bedford', 'Bracknell Forest',
#        'Reading', 'Slough', 'West Berkshire', 'Windsor and Maidenhead',
#        'Wokingham',
#        'Bracknell Forest|Reading|Slough|West Berkshire|Windsor and Maidenhead|Wokingham',
#        nan, 'Buckinghamshire', 'City of London',
#        'East Sussex|Brighton and Hove', 'Essex|Southend-on-Sea|Thurrock',
#        'Barnet', 'Bexley', 'Bromley', 'Camden', 'Croydon', 'Ealing',
#        'Enfield', 'Greenwich', 'Hackney', 'Haringey', 'Harrow',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kingston upon Thames',
#        'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster',
# ...

# %%
#13 find min (only for numerical)
dataset.min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# administrative_area_level_1     England
# administrative_area_level_2    Aberdeen
# tag                             borough
# dtype: object

# %%
#14 find max (only for numerical)
dataset.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# administrative_area_level_1       Wales
# administrative_area_level_2     Wrexham
# tag                            district
# dtype: object

# %%
#15 find sum (only for numerical)
dataset.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# administrative_area_level_1    EnglandEnglandEnglandEnglandEnglandEnglandEngl...
# administrative_area_level_2    BedfordshireBedfordshireBedfordshireBedfordshi...
# tag                            boroughboroughboroughcountyboroughboroughborou...
# dtype: object

# %%
#16 find count
dataset.count()
# Out:
# administrative_area_level_1    306
# administrative_area_level_2    306
# administrative_area_level_3    192
# tag                            306
# features                        47
# url_shape                      298
# url                            304
# dtype: int64
